# %%
import pandas as pd
import numpy as np

from chain import chain
from system_prompt import system_prompt

# %%
data = pd.read_csv("data.csv")

# %%
map_input = {
    "prompt_input" :  { "audience" : "Executive leadership",
                        "tone" : "Insightful & advisory",
                        "system_prompt" : system_prompt
                      },
    "data" : data,
    "date_col" : "order_date",
    "metric_col" : "revenue",
    "category_col" : None
}

# %%
output = chain.invoke(map_input)

# %%
print(output)
